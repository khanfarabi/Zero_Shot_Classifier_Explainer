# %%
import numpy as np
import operator
import matplotlib.pyplot as plt
from transformers import pipeline
from pylab import rcParams
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from transformers_interpret import ZeroShotClassificationExplainer
zero_shot_classifier = pipeline("zero-shot-classification")
tokenizer = AutoTokenizer.from_pretrained("Recognai/zeroshot_selectra_medium")#("facebook/bart-base-mnli")#("Recognai/zeroshot_selectra_medium")
model = AutoModelForSequenceClassification.from_pretrained("Recognai/zeroshot_selectra_medium")#("facebook/bart-base-mnli")#("Recognai/zeroshot_selectra_medium")
zero_shot_explainer = ZeroShotClassificationExplainer(model, tokenizer)

import nltk
nltk.download('wordnet')

import nltk
from stop_words import get_stop_words
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = list(get_stop_words('en'))         #Have around 900 stopwords
nltk_words = list(stopwords.words('english'))   #Have around 150 stopwords
stop_words.extend(nltk_words)


#Sentiment explanation

from transformers import AutoModelForSequenceClassification, AutoTokenizer
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
model_new = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
from transformers_interpret import SequenceClassificationExplainer
cls_explainer = SequenceClassificationExplainer(model_new,tokenizer)

# With both the model and tokenizer initialized we are now able to get explanations on an example text.

from transformers_interpret import SequenceClassificationExplainer
def review_explain(text):
        result = zero_shot_classifier(
          sequences =text,candidate_labels = ['Positive', 'Negative'],multi_label= False)
        
        #zero_shot_explainer = ZeroShotClassificationExplainer(model, tokenizer)

       # print(result)
        #word_attributions = zero_shot_explainer(text,labels = ["Positive", "Negative"],)
        #return word_attributions,zero_shot_explainer.predicted_label
        return result['labels']#,word_attributions,zero_shot_explainer.predicted_label
fh=open("hotel.txt")
ht={}
mv={}

for k in fh:
  hh=k.strip("\n").split("::")
  #print(hh)
  ht[hh[0]]=hh[1].split()
  #print("\n")
fh.close()
fh1=open("imdb.txt")
for k in fh1:
  hh=k.strip("\n").split("::")
  #print(hh)
  mv[hh[0]]=hh[1].split()
  #print("\n")
fh1.close()

import sys
#sys.exit()

htt_cls={}
htt_rank={}         
cn=0
print("Hotel Review")
for jz in ht:
  if cn<100:#0000:
            #print("heloooooooooooooo")
            #print(ht[j])
            s=""
            zz=0
            htt_exp={}
            gg=[]
            for vv in ht[jz]:
              if len(vv)>=5:
                #if zz<100:
                if vv not in stop_words:
                    s=s+str(vv)+" "
                    zz=zz+1
            #print(j,str(s))
            #sys.exit()
            clp=review_explain(s)
            htt_cls[jz]=clp[0]
            word_attributions = zero_shot_explainer(s,labels = [clp[0]],)

            #attp,expp=review_explain(s)
            #("Today apple released the new Macbook showing off a range of new features found in the proprietary silicon chip computer.")
            #if str(clp[0])==str(expp):
            #print(clp[0]) sorted(dc.items(), key=operator.itemgetter(1),reverse=True)
            #att_words= cls_explainer(s, class_name=clp[0].upper())
            #print("Predicted Sentiment Class: "+"\n"+str(clp[0])+"\n")
            from nltk.stem import WordNetLemmatizer
            lemmatizer = WordNetLemmatizer()
            from nltk.stem import PorterStemmer
            from nltk.tokenize import word_tokenize
            
            hhh=[]
            for hh in word_attributions[clp[0]]:#att_words:
              if hh[1]>0:
                if hh[0]. isalnum():
                  vvv=lemmatizer.lemmatize(str(hh[0]))
                  for bn in ht[jz]:
                    if bn.__contains__(str(vvv)):
                       if bn not in htt_exp:
                            htt_exp[bn]=float(hh[1])
            #print(htt_exp)
            #cn=cn+1
            #sys.exit()
            rankk=sorted(htt_exp.items(), key=operator.itemgetter(1),reverse=True)
            
            c1=0
            for t in rankk:
              if c1<20:
                gg.append(t[0])
                c1=c1+1
            htt_rank[jz]=gg
            cn=cn+1
            if len(gg)>=5 and str(clp[0])==str(zero_shot_explainer.predicted_label):
              print("Hotel_Review_Id: "+str(jz)+"\n")
              #print(str())
              print("Predicted Sentiment Class: "+"\n"+str(clp[0])+"\n")
              print("Explanation Attention Words in the text to justify the prediction\n"+str(gg)+"\n")
              #  print("Visualize the Attention Words")
              # cls_explainer.visualize("distilbert_viz.html")
              print("\n\n")
              
print("Movie Review")
for jz in mv:
  if cn<1000:#0000:
            #print("heloooooooooooooo")
            #print(ht[j])
            s=""
            zz=0
            htt_exp={}
            gg=[]
            for vv in mv[jz]:
              if len(vv)>=5:
                #if zz<100:
                if vv not in stop_words:
                    s=s+str(vv)+" "
                    zz=zz+1
            #print(j,str(s))
            #sys.exit()
            clp=review_explain(s)
            htt_cls[jz]=clp[0]
            word_attributions = zero_shot_explainer(s,labels = [clp[0]],)

            #attp,expp=review_explain(s)
            #("Today apple released the new Macbook showing off a range of new features found in the proprietary silicon chip computer.")
            #if str(clp[0])==str(expp):
            #print(clp[0]) sorted(dc.items(), key=operator.itemgetter(1),reverse=True)
            #att_words= cls_explainer(s, class_name=clp[0].upper())
            #print("Predicted Sentiment Class: "+"\n"+str(clp[0])+"\n")
            from nltk.stem import WordNetLemmatizer
            lemmatizer = WordNetLemmatizer()
            from nltk.stem import PorterStemmer
            from nltk.tokenize import word_tokenize
            
            hhh=[]
            for hh in word_attributions[clp[0]]:#att_words:
              if hh[1]>0:
                if hh[0]. isalnum():
                  vvv=lemmatizer.lemmatize(str(hh[0]))
                  for bn in ht[jz]:
                    if bn.__contains__(str(vvv)):
                       if bn not in htt_exp:
                            htt_exp[bn]=float(hh[1])
            #print(htt_exp)
            #cn=cn+1
            #sys.exit()
            rankk=sorted(htt_exp.items(), key=operator.itemgetter(1),reverse=True)
            
            c1=0
            for t in rankk:
              if c1<20:
                gg.append(t[0])
                c1=c1+1
            htt_rank[jz]=gg
            cn=cn+1
            if len(gg)>=5 and str(clp[0])==str(zero_shot_explainer.predicted_label):
              print("Movie_Review_Id: "+str(jz)+"\n")
              #print(str())
              print("Predicted Sentiment Class: "+"\n"+str(clp[0])+"\n")
              print("Explanation Attention Words in the text to justify the prediction\n"+str(gg)+"\n")
              #  print("Visualize the Attention Words")
              # cls_explainer.visualize("distilbert_viz.html")
              print("\n\n")
              
#print("\n\n")  


#return htt_cls,htt_rank,cls_explainer

#htt_cls,htt_rank,cls_explainer=hotel_review(ht)
'''
for tt in htt_cls:
  print("Hotel_Review_Id: "+str(tt)+"\n")
  #print(str())
  print("Predicted Sentiment Class: "+"\n"+str(htt_cls[tt])+"\n")
  print("Explanation Attention Words in the text to justify the prediction"+str(htt_rank[tt])+"\n")
  print("Visualize the Attention Words")
  cls_explainer.visualize("distilbert_viz.html")
  print("\n\n")

'''
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Hotel Review
# Hotel_Review_Id: 0
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['tired', 'order', 'recording', 'angry', 'change', 'new', 'newer', 'booking', 'booked', 'small', 'smell', 'smaller', 'duplex', 'planing', 'am', 'that', 'made', 'available', 'via', 'all']
#
#
#
#
# Hotel_Review_Id: 2
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['badly', 'prices', 'offered', 'offer', 'pictures', 'midnight', 'different', 'already', 'understand', 'common', 'complained', 'something', 'drain', 'white', 'shower', 'shift', 'signs', 'dirty', 'sleep', 'pretty']
#
#
#
#
# Hotel_Review_Id: 3
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['extreamly', 'website', 'you', 'your', 'pictures', 'thought', 'could', 'suite', 'confused', 'disgruntled', 'through', 'much', 'up', 'using', 'consumer', 'told', 'grouped', 'realised', 'really', 'showed']
#
#
#
#
# Hotel_Review_Id: 5
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['change', 'changed', 'cleaner', 'clean', 'duvet']
#
#
#
#
# Hotel_Review_Id: 7
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['clock', 'though', 'the', 'that', 'clean', 'actual', 'pictures']
#
#
#
#
# Hotel_Review_Id: 9
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['workers', 'wood', 'down', 'with', 'wrong', 'view', 'between', 'price', 'minutes', 'room', 'rooms', 'loading', 'hotel', 'telephone', 'started', 'stupid', 'system', 'staff', 'windows', 'pointed']
#
#
#
#
# Hotel_Review_Id: 13
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['space', 'although', 'breakfast', 'small', 'tricky', 'stayed', 'evening', 'badly', 'included']
#
#
#
#
# Hotel_Review_Id: 14
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['issues', 'issue', 'floor', 'staircase', 'everyday', 'daily', 'electronic', 'arrival', 'steep', 'updated', 'upon']
#
#
#
#
# Hotel_Review_Id: 16
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['dirty', 'dirt', 'disaster', 'disturbing', 'worst', 'room', 'rooms', 'bathroom', 'black', 'found', 'for', 'design', 'appeared', 'spend', 'moved', 'euros']
#
#
#
#
# Hotel_Review_Id: 17
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['sadly', 'feel', 'feeling', 'that', 'half', 'had', 'has', 'hair', 'hallway', 'what', 'have', 'happy', 'lot', 'closed', 'loudly', 'close', 'cannot', 'clean', 'and', 'cleaning']
#
#
#
#
# Hotel_Review_Id: 19
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['bathroom', 'the', 'theory', 'black', 'glass', 'however', 'hall', 'allow', 'leaves', 'leaked', 'shower', 'space', 'chairs']
#
#
#
#
# Hotel_Review_Id: 20
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['course', 'people', 'bedroom', 'be', 'at', 'all', 'slam', 'as', 'leave', 'having', 'lay', 'prepared', 'awake', 'than', 'that', 'fault']
#
#
#
#
# Hotel_Review_Id: 22
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['handrail', 'precarious', 'needed', 'something', 'luggage', 'floorplans', 'every', 'duplexes']
#
#
#
#
# Hotel_Review_Id: 24
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['scaffolding', 'extensive', 'restorations', 'still', 'temporary', 'hospital', 'works', 'work', 'completed', 'building', 'fabulous', 'but', 'aspects']
#
#
#
#
# Hotel_Review_Id: 25
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['bathroom', 'mattress', 'included', 'museums', 'order', 'handles', 'chair', 'slippery', 'close']
#
#
#
#
# Hotel_Review_Id: 30
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['apart', 'booked', 'nights', 'suppose', 'hotel', 'great', 'staring', 'window', 'perfect', 'really', 'stayed']
#
#
#
#
# Hotel_Review_Id: 31
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['going', 'good', 'and', 'ran', 'gentleman', 'training', 'was', 'totally', 'asked', 'had', 'make', 'contact', 'say', 'answer', 'manager', 'around', 'unfortunately', 'what', 'temporary', 'area']
#
#
#
#
# Hotel_Review_Id: 32
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['first', 'to', 'towards', 'reception', 'little', 'street', 'around', 'rooms', 'room', 'opening', 'required', 'necessary', 'standard', 'rather', 'floor']
#
#
#
#
# Hotel_Review_Id: 33
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['that', 'attention', 'rate', 'tired', 'building', 'but', 'this', 'issues', 'mechanism', 'missing', 'is', 'broken', 'signs', 'rooms', 'room', 'bathroom', 'overflowed', 'overloading', 'reported', 'temporary']
#
#
#
#
# Hotel_Review_Id: 34
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['staff', 'construction', 'although', 'work', 'worked', 'working', 'serving', 'interested', 'process', 'ceilings', 'forget', 'for', 'breakfast', 'check', 'cappuccino', 'more', 'morning']
#
#
#
#
# Hotel_Review_Id: 36
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['was', 'awful', 'take', 'mistake', 'part', 'after', 'asked', 'about', 'to', 'ownership', 'of', 'on', 'morning', 'refused']
#
#
#
#
# Hotel_Review_Id: 37
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['lower', 'either', 'cooling', 'replenished', 'celcius', 'degrees', 'bathroom']
#
#
#
#
# Hotel_Review_Id: 38
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['pretty', 'was', 'wandered', 'anyway', 'walking', 'concrete', 'courtyard', 'comes', 'point', 'pointless', 'some', 'someone', 'smelled', 'somewhere', 'meant', 'hotel', 'toilet', 'to', 'together', 'menditory']
#
#
#
#
# Hotel_Review_Id: 40
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['super', 'found', 'stiff', 'stay', 'towels', 'break', 'service']
#
#
#
#
# Hotel_Review_Id: 41
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['early', 'midnight', 'night', 'quite', 'amsterdam']
#
#
#
#
# Hotel_Review_Id: 42
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['cleaner', 'petals', 'twice', 'extra', 'was', 'wasn', 'waited', 'arriving', 'had', 'pay', 'tax', 'that', 'paid', 'changed', 'made', 'said', 'call', 'taxi', 'after', 'asked']
#
#
#
#
# Hotel_Review_Id: 43
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['opening', 'water', 'shower', 'garage', 'window', 'whole', 'curtained', 'construction']
#
#
#
#
# Hotel_Review_Id: 45
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['narrow', 'carried', 'night', 'middle', 'unavoidable']
#
#
#
#
# Hotel_Review_Id: 47
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['whoever', 'with', 'worst', 'how', 'overflows', 'woke', 'review', 'written', 'new', 'easily', 'area', 'measures', 'need', 'needs', 'management', 'outside', 'staff', 'reception', 'property', 'completely']
#
#
#
#
# Hotel_Review_Id: 50
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['attitude', 'at', 'water', 'heater', 'manager', 'machine', 'sound', 'coffee']
#
#
#
#
# Hotel_Review_Id: 55
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['glass', 'bathroom', 'the', 'though', 'they', 'think', 'times', 'friends']
#
#
#
#
# Hotel_Review_Id: 57
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['guests', 'interested', 'spoons', 'but', 'butter']
#
#
#
#
# Hotel_Review_Id: 60
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['upgraded', 'noise', 'perfectly', 'bothered', 'changed', 'annexe', 'change', 'and', 'offered', 'sized', 'arrival', 'unfortunately', 'had', 'cigarettes', 'attic', 'heater', 'asked', 'again', 'back', 'regular']
#
#
#
#
# Hotel_Review_Id: 61
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['serving', 'affect', 'comfortable', 'recommend', 'complete', 'staying', 'modesty', 'guests', 'restaurant', 'stranger', 'still', 'start', 'little', 'facilities', 'concerned', 'corner', 'black', 'practically', 'across', 'lack']
#
#
#
#
# Hotel_Review_Id: 62
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['booking', 'workers', 'massive', 'around', 'hotel', 'construction']
#
#
#
#
# Hotel_Review_Id: 65
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['spice', 'better', 'check', 'regulary', 'varpet', 'place', 'pillows', 'rooms', 'room']
#
#
#
#
# Hotel_Review_Id: 67
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['renovated', 'noise', 'no', 'noisy', 'room', 'rooms', 'people', 'building', 'currently', 'hotel']
#
#
#
#
# Hotel_Review_Id: 69
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['girlfriend', 'walk', 'walking', 'around', 'building']
#
#
#
#
# Hotel_Review_Id: 70
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['no', 'noisy', 'not', 'maintenance', 'make', 'information', 'warning', 'hotel', 'token', 'to', 'facade', 'minibar', 'barrier', 'stained', 'staircase', 'understaffed', 'carpet']
#
#
#
#
# Hotel_Review_Id: 72
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['booked', 'bathroom', 'given', 'change', 'coming', 'twins']
#
#
#
#
# Hotel_Review_Id: 73
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['declined', 'guests', 'still', 'allowing', 'partially', 'some', 'somewhat', 'group', 'leaves', 'heating', 'earlier', 'breakfast', 'official', 'checkout', 'checkin', 'service', 'major', 'renovation', 'system', 'stay']
#
#
#
#
# Hotel_Review_Id: 74
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['steamed', 'going', 'everywhere', 'panels', 'shower']
#
#
#
#
# Hotel_Review_Id: 76
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['hands', 'and', 'endangering', 'chance', 'anyway', 'endanger', 'any', 'cleaner', 'granted', 'picture', 'covered', 'happened', 'discharged', 'what', 'had', 'have', 'charge', 'managemt', 'management', 'managent']
#
#
#
#
# Hotel_Review_Id: 77
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['blocked', 'bathroom', 'shower', 'common', 'everywhere', 'everytime', 'flooded']
#
#
#
#
# Hotel_Review_Id: 80
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['birthday', 'blocked', 'overall', 'shower', 'flood', 'website', 'we', 'were', 'allowed', 'weekend', 'package', 'unaware', 'unable', 'minutes', 'taxes', 'standard', 'breakfast', 'suggest', 'staff', 'still']
#
#
#
#
# Hotel_Review_Id: 81
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['sound', 'split', 'downstairs', 'proofing', 'bedrooms', 'walls', 'quirky']
#
#
#
#
# Hotel_Review_Id: 82
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['renovations', 'booking', 'mention', 'waking', 'hotels']
#
#
#
#
# Hotel_Review_Id: 83
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['narrow', 'difficult', 'steep', 'this', 'with', 'the', 'think', 'hotel', 'general', 'sticky']
#
#
#
#
# Hotel_Review_Id: 84
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['restaurant', 'night', 'there', 'the', 'things', 'they', 'though', 'was', 'and', 'asked', 'about', 'alot', 'staff', 'that', 'walk', 'table', 'take', 'plates', 'day', 'immediately']
#
#
#
#
# Hotel_Review_Id: 87
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['however', 'breakfast', 'spaced', 'combined', 'efficient', 'at', 'tended', 'attendants']
#
#
#
#
# Hotel_Review_Id: 88
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['smell', 'small', 'areas', 'common', 'banisters', 'overprices', 'overall', 'design', 'musty', 'restaurant', 'throughout', 'place', 'dangerous', 'impractical']
#
#
#
#
# Hotel_Review_Id: 91
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['hotel', 'ongoing', 'front', 'soon', 'hopefully', 'completed', 'renovation']
#
#
#
#
# Hotel_Review_Id: 92
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['things', 'they', 'bathroom', 'deliver', 'generally', 'cramped', 'distant']
#
#
#
#
# Hotel_Review_Id: 96
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['quite', 'really', 'bathroom', 'member', 'proved', 'showering', 'deducted', 'blocking', 'to', 'toilet', 'told', 'into', 'security', 'charged']
#
#
#
#
# Hotel_Review_Id: 97
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['renovation', 'enough', 'compensation', 'booking', 'mention', 'gardens', 'cocktails', 'voucher', 'drink', 'sidewalk']
#
#
#
#
# Hotel_Review_Id: 98
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['major', 'anyone', 'anything', 'recommend', 'staircase', 'restaurant', 'staff', 'despite', 'to', 'toilet', 'construction', 'going', 'returning', 'friendly', 'dangerous', 'experience']
#
#
#
#
# Movie Review
# Movie_Review_Id: 0
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['planing', 'in', 'ceilings', 'mind', 'rain', 'mini', 'explaining', 'ceiling', 'begin', 'internal', 'waiting', 'evening', 'vibrating', 'making', 'determine', 'disturbing', 'again', 'that', 'mistake', 'stayed']
#
#
#
#
# Movie_Review_Id: 1
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['single', 'fridge', 'with', 'the', 'level']
#
#
#
#
# Movie_Review_Id: 2
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['the', 'rainfall', 'overall', 'all', 'challenges', 'complained', 'late', 'this', 'something', 'that', 'with', 'staff', 'request', 'amsterdam', 'guests', 'understand', 'inconsistent', 'last']
#
#
#
#
# Movie_Review_Id: 3
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['showed', 'with', 'thought', 'then', 'that', 'the', 'theough', 'them', 'there', 'together', 'birthday', 'through', 'something', 'me', 'consumer']
#
#
#
#
# Movie_Review_Id: 7
#
# Predicted Sentiment Class:
# Negative
#
# Explanation Attention Words in the text to justify the prediction
# ['show', 'was', 'though', 'the', 'that', 'clean', 'actual', 'and', 'also', 'at', 'ready']
#
#
#
#
# Movie_Review_Id: 9
#
# Predicted Sentiment Class:
# Positive
#
# Explanation Attention Words in the text to justify the prediction
# ['late', 'workers', 'wood', 'down', 'windows', 'with', 'wrong', 'view', 'between']
